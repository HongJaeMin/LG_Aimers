# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn import linear_model

# %%
train_df = pd.read_csv('C:\\VSC\\LG_Aimers\\train_2.csv')
test_df = pd.read_csv('C:\\VSC\\LG_Aimers\\test_2.csv')

train_df = train_df.set_index("TIMESTAMP")
test_df = test_df.set_index("TIMESTAMP")

# %% [markdown]
# pd.set_option('display.max_rows', 100)
# pd.set_option('display.max_columns', 100)

# %% [markdown]
# Xns_COUNT = Xns.iloc[:, 0:1]
# a = Xns_COUNT.COUNT.unique()
#
# Xns_COUNT_lists = [
#     0, 6, 10, 23, 33, 39, 42, 52, 59, 62,
#     70, 78, 87, 94, 99, 100, 104, 110, 118, 119,
#     120, 129, 174, 175, 233, 247, 248, 249, 348, 349
# ]
#
# for Xns_COUNT_list in Xns_COUNT_lists:
#     a = Xns_COUNT.loc[Xns_COUNT.COUNT == Xns_COUNT_list].index
#     globals()["Xns_COUNT_{}".format(Xns_COUNT_list)] = a

# %% [markdown]
# pd.DataFrame(train_df.iloc[:, 6:106].mean())

# %% [markdown]
# train_df.head()

# %% [markdown]
# train_Xn_df_NULL = pd.DataFrame({"COUNT" : train_df.iloc[:, 5:2881].count()})
# a = train_Xn_df_NULL.loc[train_Xn_df_NULL.COUNT == 0]
# print(a.index)
# print(a.shape[0])

# %%
a = train_df.loc[train_df.Y_Class == 0]
b = train_df.loc[train_df.Y_Class == 1]
c = train_df.loc[train_df.Y_Class == 2]

C_0 = a
C_1 = b
C_2 = c

# %%
a = C_0.CODE_LINE.unique()
b = C_1.CODE_LINE.unique()
c = C_2.CODE_LINE.unique()

print("-- C_0 CODE_LINE --\n{}\n\n-- C_1 CODE_LINE --\n{}\n\n-- C_2 CODE_LINE --\n{}".format(a, b, c))
# Out:
# -- C_0 CODE_LINE --
# ['T100304' 'A010305' 'A050304' 'A010306' 'T100306' 'A050307']
#
# -- C_1 CODE_LINE --
# ['A050304' 'T100304' 'T100306' 'A010305' 'A050307' 'A010306' 'O100304'
#  'O100306']
#
# -- C_2 CODE_LINE --
# ['A050307' 'A050304' 'A010306' 'A010305' 'T100304' 'T100306' 'O100306']

# %% [markdown]
# # **0, 1, 2 : 겹치는 CODE_LINE**
#
# - A050304
#
# - T100304
#
# - A010305
#
# - A010306
#
# - T100306
#
# - A050307

# %% [markdown]
# ## A050304 : C_0
# - 최대 카운트 30
#
# - 카운트 0 : 907개 열
# - 카운트 9 : 420개 열
# - 카운트 1 : 60개 열
# - 카운트 6 : 11개 열
# - 카운트 2 : 5개 열

# %%
C_0_A050304 = C_0.loc[C_0.CODE_LINE == "A050304"]
C_0_A050304 = C_0_A050304.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_0_A050304.head()
# Out:
#                      Y_Quality  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  \
# TIMESTAMP
# 2022-06-21 17:36:00   0.521524  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-06 19:15:00   0.516711  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-06 19:23:00   0.519451  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-06 20:41:00   0.518960  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-10 00:57:00   0.519810  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                      ...  X_2866  X_2867  X_2868  X_2869  X_2870  X_2871  \
# TIMESTAMP            ...
# 2022-06-21 17:36:00  ...   55.03   52.24   55.33   57.49   67.31     1.0
# 2022-07-06 19:15:00  ...   56.86   50.46   40.49   57.34   66.37     1.0
# 2022-07-06 19:23:00  ...   48.28   51.25   55.43   56.95   67.44     1.0
# 2022-07-06 20:41:00  ...     NaN     NaN     NaN     NaN     NaN     1.0
# 2022-07-10 00:57:00  ...   52.97   59.15   42.29   57.22   65.46     1.0
#
# ...

# %%
C_0_A050304_des = pd.DataFrame({
    "COUNT" : C_0_A050304.count(),
    "MEAN" : C_0_A050304.mean(),
    "STD" : C_0_A050304.std(),
    "MIN" : C_0_A050304.min(),
    "Q1" : C_0_A050304.quantile(0.25),
    "Q2" : C_0_A050304.quantile(0.5),
    "Q3" : C_0_A050304.quantile(0.75),
    "MAX" : C_0_A050304.max()
})

C_0_A050304_des.COUNT.value_counts()
# Out:
# 0     907
# 30    905
# 9     420
# 28    395
# 29    145
# 1      60
# 24     26
# 6      11
# 2       5
# 23      1
# 27      1
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 30개 중에서 20개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_0_A050304_des.loc[(C_0_A050304_des.COUNT >= 20) & (C_0_A050304_des.COUNT < 30)]
# Out:
#         COUNT       MEAN       STD        MIN         Q1         Q2  \
# X_938      28   2.007500  1.719607   0.310000   0.582500   0.750000
# X_939      28   1.915692  1.718009   0.286129   0.498065   0.640161
# X_940      28   1.810357  1.694139   0.270000   0.387500   0.565000
# X_941      28  75.867857  0.525677  75.200000  75.575000  75.700000
# X_942      28  75.646378  0.505688  75.022581  75.305645  75.524194
# ...       ...        ...       ...        ...        ...        ...
# X_2866     24  53.068750  3.249586  47.190000  50.607500  54.115000
# X_2867     24  55.684167  4.019735  47.840000  52.610000  54.710000
# X_2868     24  49.493333  6.708437  36.810000  41.985000  52.510000
# X_2869     24  55.706667  2.500817  49.390000  55.292500  56.300000
# X_2870     24  65.040000  1.576038  62.610000  63.622500  65.035000
#
#                Q3        MAX
# X_938    3.447500   4.970000
# X_939    3.355806   4.904194
# X_940    3.260000   4.810000
# X_941   76.025000  77.400000
# ...

# %%
with open('C:\\VSC\\LG_Aimers\\2_2_Xn_txt\\C_0_A050304_20_30.txt', 'w', encoding='UTF-8') as f:
    for name in C_0_A050304_des.loc[(C_0_A050304_des.COUNT >= 20) & (C_0_A050304_des.COUNT < 30)].index:
        f.write(name+'\n')

# %%
f = open('C:\\VSC\\LG_Aimers\\2_2_Xn_txt\\C_0_A050304_20_30.txt','r')
C_0_A050304_20_30 = f.read()
f.close()
C_0_A050304_20_30
# Out:
# 'X_938\nX_939\nX_940\nX_941\nX_942\nX_943\nX_944\nX_945\nX_946\nX_947\nX_948\nX_949\nX_950\nX_951\nX_952\nX_953\nX_954\nX_957\nX_958\nX_959\nX_960\nX_961\nX_962\nX_963\nX_964\nX_965\nX_966\nX_967\nX_968\nX_969\nX_970\nX_971\nX_972\nX_973\nX_974\nX_975\nX_976\nX_977\nX_978\nX_979\nX_980\nX_981\nX_982\nX_983\nX_984\nX_985\nX_986\nX_987\nX_988\nX_989\nX_990\nX_991\nX_992\nX_993\nX_994\nX_995\nX_996\nX_997\nX_998\nX_999\nX_1000\nX_1001\nX_1006\nX_1007\nX_1008\nX_1009\nX_1010\nX_1011\nX_1012\nX_1013\nX_1014\nX_1015\nX_1016\nX_1017\nX_1018\nX_1019\nX_1020\nX_1021\nX_1022\nX_1023\nX_1024\nX_1025\nX_1026\nX_1027\nX_1028\nX_1029\nX_1030\nX_1031\nX_1032\nX_1033\nX_1034\nX_1035\nX_1036\nX_1037\nX_1038\nX_1039\nX_1040\nX_1041\nX_1042\n
_df[col].loc[(train_df.Y_Class == 0) & (train_df.CODE_LINE == "A050304")].fillna(
# X_938 ... 30
# X_939 ... 30
# X_940 ... 30
# X_941 ... 30
# X_942 ... 30
# X_943 ... 30
# X_944 ... 30
# X_945 ... 30
# X_946 ... 30
# X_947 ... 30
# X_948 ... 30
# X_949 ... 30
# X_950 ... 30
# X_951 ... 30
# X_952 ... 30
# X_953 ... 30
# X_954 ... 30
# X_957 ... 30
# X_958 ... 30
# X_959 ... 30
# X_960 ... 30
# X_961 ... 30
# X_962 ... 30
# X_963 ... 30
# X_964 ... 30
# X_965 ... 30
# X_966 ... 30
# X_967 ... 30
# X_968 ... 30
# X_969 ... 30
# X_970 ... 30
# X_971 ... 30
# X_972 ... 30
# X_973 ... 30
# X_974 ... 30
# ...

# %% [markdown]
# ## A050304 : C_1
# - 최대 카운트 37
#
# - 카운트 0 : 907개 열
# - 카운트 15 : 70개 열
# - 카운트 1 : 5개 열
# - 카운트 18 : 1개 열

# %%
C_1_A050304 = C_1.loc[C_1.CODE_LINE == "A050304"]
C_1_A050304 = C_1_A050304.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_1_A050304.head()
# Out:
#                      Y_Quality  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  \
# TIMESTAMP
# 2022-06-13 05:14:00   0.533433  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-13 05:30:00   0.531267  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-13 05:47:00   0.531590  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-13 06:03:00   0.533665  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-13 06:19:00   0.531821  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                      ...  X_2866  X_2867  X_2868  X_2869  X_2870  X_2871  \
# TIMESTAMP            ...
# 2022-06-13 05:14:00  ...   39.34   40.89   32.56   34.09   77.77     NaN
# 2022-06-13 05:30:00  ...   39.19   36.65   42.47   36.53   78.35     NaN
# 2022-06-13 05:47:00  ...   38.70   41.89   46.93   33.09   76.97     NaN
# 2022-06-13 06:03:00  ...   32.50   41.42   38.36   30.83   76.93     NaN
# 2022-06-13 06:19:00  ...   42.25   43.17   55.60   33.26   78.50     NaN
#
# ...

# %%
C_1_A050304_des = pd.DataFrame({
    "COUNT" : C_1_A050304.count(),
    "MEAN" : C_1_A050304.mean(),
    "STD" : C_1_A050304.std(),
    "MIN" : C_1_A050304.min(),
    "Q1" : C_1_A050304.quantile(0.25),
    "Q2" : C_1_A050304.quantile(0.5),
    "Q3" : C_1_A050304.quantile(0.75),
    "MAX" : C_1_A050304.max()
})

C_1_A050304_des.COUNT.value_counts()
# Out:
# 37    1441
# 0      907
# 24     420
# 15      70
# 34      26
# 1        5
# 32       3
# 33       1
# 30       1
# 18       1
# 26       1
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 37개 중에서 24개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_1_A050304_des.loc[(C_1_A050304_des.COUNT >= 24) & (C_1_A050304_des.COUNT < 37)]
# Out:
#         COUNT           MEAN           STD            MIN             Q1  \
# X_990      32     163.937500      0.245935     163.000000     164.000000
# X_991      32  111281.250000  11860.028763  101000.000000  102000.000000
# X_1174     33       2.754545      6.672054       0.900000       1.000000
# X_1175     32      11.718750      0.581121      11.000000      11.000000
# X_1408     30      34.097332     56.090585      -1.854354       3.441366
# ...       ...            ...           ...            ...            ...
# X_2867     34      52.194118      9.410584      31.700000      44.472500
# X_2868     34      48.394412      7.729129      32.560000      40.510000
# X_2869     34      49.036765     10.559114      30.720000      35.930000
# X_2870     34      68.318235      6.265298      61.670000      63.770000
# X_2871     26       1.000000      0.000000       1.000000       1.000000
#
#                   Q2            Q3            MAX
# ...

# %%
with open('C:\\VSC\\LG_Aimers\\2_2_Xn_txt\\C
_df[col].loc[(train_df.Y_Class == 1) & (train_df.CODE_LINE == "A050304")] = train_df[col].loc[(train_df.Y_Class == 1) & (train_df.CODE_LINE == "A050304")].fillna(
                                                                                        train_df[col].loc[(train_df.Y_Class == 1) & (train_df.CODE_LINE == "A050304")].mean())
    
    a = train_df[col].loc[(train_df.Y_Class == 1) & (train_df.CODE_LINE == "A050304")].count()
    print("{} ... {}".format(col, a))
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_4668\985175256.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[col].loc[(train_df.Y_Class == 1) & (train_df.CODE_LINE == "A050304")] = train_df[col].loc[(train_df.Y_Class == 1) & (train_df.CODE_LINE == "A050304")].fillna(
# X_990 ... 37
# X_991 ... 37
# X_1174 ... 37
# X_1175 ... 37
# X_1408 ... 37
# X_1951 ... 37
# X_1952 ... 37
# X_1953 ... 37
# X_1954 ... 37
# X_1955 ... 37
# X_1956 ... 37
# X_1957 ... 37
# X_1958 ... 37
# X_1959 ... 37
# X_1960 ... 37
# X_1961 ... 37
# X_1962 ... 37
# X_1963 ... 37
# X_1964 ... 37
# X_1965 ... 37
# X_1966 ... 37
# X_1967 ... 37
# X_1968 ... 37
# X_2041 ... 37
# X_2042 ... 37
# X_2043 ... 37
# X_2063 ... 37
# X_2064 ... 37
# X_2065 ... 37
# X_2066 ... 37
# X_2067 ... 37
# X_2068 ... 37
# X_2069 ... 37
# ...

# %% [markdown]
# ## A050304 : C_2
# - 최대 카운트 11
#
# - 카운트 0 : 907개 열
# - 카운트 6 : 420개 열
# - 카운트 3 : 70개 열
# - 카운트 1 : 5개 열
# - 카운트 2 : 1개 열

# %%
C_2_A050304 = C_2.loc[C_2.CODE_LINE == "A050304"]
C_2_A050304 = C_2_A050304.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_2_A050304.head()
# Out:
#                      Y_Quality  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  \
# TIMESTAMP
# 2022-06-14 05:58:00   0.544129  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-01 00:54:00   0.538629  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-01 01:11:00   0.537733  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-19 06:27:00   0.535405  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-31 14:15:00   0.537046  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                      ...  X_2866  X_2867  X_2868  X_2869  X_2870  X_2871  \
# TIMESTAMP            ...
# 2022-06-14 05:58:00  ...     NaN     NaN     NaN     NaN     NaN     1.0
# 2022-07-01 00:54:00  ...   53.49   55.59   60.00   58.18   66.79     1.0
# 2022-07-01 01:11:00  ...   55.89   63.42   42.71   57.03   66.20     1.0
# 2022-07-19 06:27:00  ...     NaN     NaN     NaN     NaN     NaN     1.0
# 2022-07-31 14:15:00  ...   53.49   58.06   33.43   54.71   61.93     1.0
#
# ...

# %%
C_2_A050304_des = pd.DataFrame({
    "COUNT" : C_2_A050304.count(),
    "MEAN" : C_2_A050304.mean(),
    "STD" : C_2_A050304.std(),
    "MIN" : C_2_A050304.min(),
    "Q1" : C_2_A050304.quantile(0.25),
    "Q2" : C_2_A050304.quantile(0.5),
    "Q3" : C_2_A050304.quantile(0.75),
    "MAX" : C_2_A050304.max()
})

C_2_A050304_des.COUNT.value_counts()
# Out:
# 11    1442
# 0      907
# 6      420
# 3       70
# 9       27
# 1        5
# 10       3
# 8        1
# 2        1
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 11개 중에서 7개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_2_A050304_des.loc[(C_2_A050304_des.COUNT >= 7) & (C_2_A050304_des.COUNT < 11)]
# Out:
#         COUNT           MEAN           STD            MIN             Q1  \
# X_990      10     163.900000  3.162278e-01     163.000000     164.000000
# X_991      10  109300.000000  1.144115e+04  102000.000000  102000.000000
# X_1174      8       1.012500  8.345230e-02       0.900000       0.975000
# X_1175     10      11.600000  5.163978e-01      11.000000      11.000000
# X_1408      9      37.794208  3.383375e+01      -2.020305      12.717004
# X_1951      9       0.166552  6.193628e-03       0.160000       0.161636
# X_1952      9       0.000014  3.820455e-06       0.000008       0.000013
# X_1953      9       0.000221  1.918371e-05       0.000196       0.000203
# X_1954      9       0.000099  4.531672e-05       0.000042       0.000044
# X_1955      9       0.000015  2.754088e-06       0.000011       0.000012
# X_1956      9       0.000005  5.465218e-07       0.000004       0.000005
# X_1957      9      78.555556  7.584707e+00      69.000000      69.000000
# ...

# %%
with open('C:\\VSC\\LG_Aimers\\2_2_Xn_txt\\C_2_A050304_7_11.txt', 'w', encoding='UTF-8') as f:
    for name in C_2_A050304_des.loc[(C_2_A050304_des.COUNT >= 7) & (C_2_A050304_des.COUNT < 11)].index:
        f.write(name+'\n')

# %%
f = open('C:\\VSC\\LG_Aimers\\2_2_Xn_txt\\C_2_A050304_7_11.txt','r')
C_2_A050304_7_11 = f.read()
f.close()
C_2_A050304_7_11
# Out:
# 'X_990\nX_991\nX_1174\nX_1175\nX_1408\nX_1951\nX_1952\nX_1953\nX_1954\nX_1955\nX_1956\nX_1957\nX_1958\nX_1959\nX_1960\nX_1961\nX_1962\nX_1963\nX_1964\nX_1965\nX_1966\nX_1967\nX_1968\nX_2041\nX_2042\nX_2043\nX_2866\nX_2867\nX_2868\nX_2869\nX_2870\n'

# %%
cols = ['X_990','X_991','X_1174','X_1175','X_1408','X_1951','X_1952','X_1953','X_1954','X_1955','X_1956','X_1957','X_1958','X_1959','X_1960','X_1961','X_1962','X_1963','X_1964','X_1965','X_1966','X_1967','X_1968','X_2041','X_2042','X_2043','X_2866','X_2867','X_2868','X_2869','X_2870']

# %%
for col in cols:
    train_df[col].loc[(train_df.Y_Class == 2) & (train_df.CODE_LINE == "A050304")] = train_df[col].loc[(train_df.Y_Class == 2) & (train_df.CODE_LINE == "A050304")].fillna(
                                                                                        train_df[col].loc[(train_df.Y_Class == 2) & (train_df.CODE_LINE == "A050304")].mean())
    
    a = train_df[col].loc[(train_df.Y_Class == 2) & (train_df.CODE_LINE == "A050304")].count()
    print("{} ... {}".format(col, a))
# Out:
# X_990 ... 11
# X_991 ... 11
# X_1174 ... 11
# X_1175 ... 11
# X_1408 ... 11
# X_1951 ... 11
# X_1952 ... 11
# X_1953 ... 11
# X_1954 ... 11
# X_1955 ... 11
# X_1956 ... 11
# X_1957 ... 11
# X_1958 ... 11
# X_1959 ... 11
# X_1960 ... 11
# X_1961 ... 11
# X_1962 ... 11
# X_1963 ... 11
# X_1964 ... 11
# X_1965 ... 11
# X_1966 ... 11
# X_1967 ... 11
# X_1968 ... 11
# X_2041 ... 11
# X_2042 ... 11
# X_2043 ... 11
# X_2866 ... 11
# X_2867 ... 11
# X_2868 ... 11
# X_2869 ... 11
# X_2870 ... 11
# C:\Users\LG\AppData\Local\Temp\ipykernel_4668\1563376270.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[col].loc[(train_df.Y_Class == 2) & (train_df.CODE_LINE == "A050304")] = train_df[col].loc[(train_df.Y_Class == 2) & (train_df.CODE_LINE == "A050304")].fillna(

# %% [markdown]
# ## T100304 : C_0
# - 최대 카운트 17
#
# - 카운트 0 : 2209개 열
# - 카운트 8 : 10개 열

# %%
C_0_T100304 = C_0.loc[C_0.CODE_LINE == "T100304"]
C_0_T100304 = C_0_T100304.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_0_T100304.head()
# Out:
#                      Y_Quality  X_1    X_2  X_3   X_4   X_5  X_6   X_7   X_8  \
# TIMESTAMP
# 2022-06-14 08:53:00   0.517719  2.0  102.0  0.0  45.0  11.0  0.0  45.0  10.0
# 2022-06-14 09:01:00   0.519090  2.0  102.0  0.0  45.0  11.0  0.0  45.0  10.0
# 2022-07-01 19:57:00   0.524419  2.0  102.0  0.0  45.0  11.0  0.0  45.0  10.0
# 2022-07-01 20:05:00   0.520078  2.0   95.0  0.0  45.0  11.0  0.0  45.0  10.0
# 2022-07-01 20:13:00   0.524862  2.0  101.0  0.0  45.0  11.0  0.0  45.0  10.0
#
#                       X_9  ...  X_2866  X_2867  X_2868  X_2869  X_2870  \
# TIMESTAMP                  ...
# 2022-06-14 08:53:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-06-14 09:01:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-07-01 19:57:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-07
_868','X_869','X_870','X_871','X_872','X_873','X_874','X_875','X_876','X_877','X_878','X_879','X_880','X_881','X_890','X_891','X_892','X_893','X_894','X_895','X_896','X_897','X_902','X_903','X_904','X_905','X_906','X_907','X_908','X_909','X_910','X_911','X_912','X_913','X_914','X_915','X_916','X_917','X_918','X_919','X_920','X_921','X_922','X_923','X_924','X_925','X_926','X_927','X_928','X_929','X_930','X_931','X_932','X_933']

# %%
for col in cols:
    train_df[col].loc[(train_df.Y_Class == 0) & (train_df.CODE_LINE == "T100304")] = train_df[col].loc[(train_df.Y_Class == 0) & (train_df.CODE_LINE == "T100304")].fillna(
                                                                                        train_df[col].loc[(train_df.Y_Class == 0) & (train_df.CODE_LINE == "T100304")].mean())
    
    a = train_df[col].loc[(train_df.Y_Class == 0) & (train_df.CODE_LINE == "T100304")].count()
    print("{} ... {}".format(col, a))
# Out:
# C:\Users\LG\AppData\Local\Temp\ipykernel_4668\4012609040.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[col].loc[(train_df.Y_Class == 0) & (train_df.CODE_LINE == "T100304")] = train_df[col].loc[(train_df.Y_Class == 0) & (train_df.CODE_LINE == "T100304")].fillna(
# X_384 ... 17
# X_385 ... 17
# X_386 ... 17
# X_387 ... 17
# X_388 ... 17
# X_389 ... 17
# X_390 ... 17
# X_391 ... 17
# X_392 ... 17
# X_393 ... 17
# X_394 ... 17
# X_395 ... 17
# X_396 ... 17
# X_397 ... 17
# X_398 ... 17
# X_399 ... 17
# X_406 ... 17
# X_407 ... 17
# X_408 ... 17
# X_409 ... 17
# X_410 ... 17
# X_411 ... 17
# X_412 ... 17
# X_413 ... 17
# X_414 ... 17
# X_415 ... 17
# X_416 ... 17
# X_417 ... 17
# X_418 ... 17
# X_419 ... 17
# X_420 ... 17
# X_421 ... 17
# X_422 ... 17
# X_423 ... 17
# X_424 ... 17
# ...

# %% [markdown]
# ## T100304 : C_1
# - 대체 없음
#
# - 최대 카운트 141
#
# - 카운트 0 : 2204개 열
# - 카운트 40 : 10개 열
# - 카운트 1 : 5개 열

# %%
C_1_T100304 = C_1.loc[C_1.CODE_LINE == "T100304"]
C_1_T100304 = C_1_T100304.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_1_T100304.head()
# Out:
#                      Y_Quality  X_1    X_2  X_3   X_4   X_5  X_6   X_7   X_8  \
# TIMESTAMP
# 2022-06-19 09:11:00   0.529362  2.0   97.0  0.0  45.0  11.0  0.0  45.0  10.0
# 2022-06-19 23:31:00   0.532405  2.0  100.0  0.0  45.0  11.0  0.0  45.0  10.0
# 2022-06-22 03:47:00   0.533110  2.0  100.0  0.0  45.0  11.0  0.0  45.0  10.0
# 2022-06-23 10:24:00   0.530948  2.0   97.0  0.0  45.0  11.0  0.0  45.0  10.0
# 2022-06-23 10:32:00   0.532219  2.0   99.0  0.0  45.0  11.0  0.0  45.0  10.0
#
#                       X_9  ...  X_2866  X_2867  X_2868  X_2869  X_2870  \
# TIMESTAMP                  ...
# 2022-06-19 09:11:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-06-19 23:31:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-06-22 03:47:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-06-23 10:24:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-06-23 10:32:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
C_1_T100304_des = pd.DataFrame({
    "COUNT" : C_1_T100304.count(),
    "MEAN" : C_1_T100304.mean(),
    "STD" : C_1_T100304.std(),
    "MIN" : C_1_T100304.min(),
    "Q1" : C_1_T100304.quantile(0.25),
    "Q2" : C_1_T100304.quantile(0.5),
    "Q3" : C_1_T100304.quantile(0.75),
    "MAX" : C_1_T100304.max()
})

C_1_T100304_des.COUNT.value_counts()
# Out:
# 0      2204
# 141     657
# 40       10
# 1         5
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 141개 중에서 94개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_1_T100304_des.loc[(C_1_T100304_des.COUNT >= 94) & (C_1_T100304_des.COUNT < 141)]
# Out:
# Empty DataFrame
# Columns: [COUNT, MEAN, STD, MIN, Q1, Q2, Q3, MAX]
# Index: []

# %% [markdown]
# ## T100304 : C_2
# - 대체 없음
#
# - 최대 카운트 14
#
# - 카운트 0 : 2209개 열
# - 카운트 1 : 10개 열

# %%
C_2_T100304 = C_2.loc[C_2.CODE_LINE == "T100304"]
C_2_T100304 = C_2_T100304.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_2_T100304.head()
# Out:
#                      Y_Quality  X_1    X_2  X_3   X_4   X_5  X_6   X_7   X_8  \
# TIMESTAMP
# 2022-06-24 09:08:00   0.545343  2.0  102.0  0.0  45.0  10.0  0.0  45.0  10.0
# 2022-07-19 22:11:00   0.536275  1.0   97.0  0.0  45.0  11.0  0.0  45.0  10.0
# 2022-07-22 08:39:00   0.535587  2.0  100.0  0.0  45.0  10.0  0.0  45.0  10.0
# 2022-07-28 08:11:00   0.542144  2.0  100.0  0.0  45.0  11.0  0.0  45.0  10.0
# 2022-07-29 12:32:00   0.545678  2.0   99.0  0.0  45.0  10.0  0.0  45.0  10.0
#
#                       X_9  ...  X_2866  X_2867  X_2868  X_2869  X_2870  \
# TIMESTAMP                  ...
# 2022-06-24 09:08:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-07-19 22:11:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-07-22 08:39:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-07-28 08:11:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-07-29 12:32:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
C_2_T100304_des = pd.DataFrame({
    "COUNT" : C_2_T100304.count(),
    "MEAN" : C_2_T100304.mean(),
    "STD" : C_2_T100304.std(),
    "MIN" : C_2_T100304.min(),
    "Q1" : C_2_T100304.quantile(0.25),
    "Q2" : C_2_T100304.quantile(0.5),
    "Q3" : C_2_T100304.quantile(0.75),
    "MAX" : C_2_T100304.max()
})

C_2_T100304_des.COUNT.value_counts()
# Out:
# 0     2209
# 14     657
# 1       10
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 14개 중에서 9개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_2_T100304_des.loc[(C_2_T100304_des.COUNT >= 9) & (C_2_T100304_des.COUNT < 14)]
# Out:
# Empty DataFrame
# Columns: [COUNT, MEAN, STD, MIN, Q1, Q2, Q3, MAX]
# Index: []

# %% [markdown]
# ## A010305 : C_0
# - 대체 없음
#
# - 최대 카운트 13
#
# - 카운트 0 : 1994개 열
# - 카운트 5 : 10개 열

# %%
C_0_A010305 = C_0.loc[C_0.CODE_LINE == "A010305"]
C_0_A010305 = C_0_A010305.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_0_A010305.head()
# Out:
#                      Y_Quality  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  \
# TIMESTAMP
# 2022-06-19 20:26:00   0.521249  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-25 21:38:00   0.524408  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-07 15:40:00   0.523714  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-07 17:24:00   0.521083  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-08 13:55:00   0.518024  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                      ...  X_2866  X_2867  X_2868  X_2869  X_2870  X_2871  \
# TIMESTAMP            ...
# 2022-06-19 20:26:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-25 21:38:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-07-07 15:40:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-07-07 17:24:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-07-08 13:55:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
C_0_A010305_des = pd.DataFrame({
    "COUNT" : C_0_A010305.count(),
    "MEAN" : C_0_A010305.mean(),
    "STD" : C_0_A010305.std(),
    "MIN" : C_0_A010305.min(),
    "Q1" : C_0_A010305.quantile(0.25),
    "Q2" : C_0_A010305.quantile(0.5),
    "Q3" : C_0_A010305.quantile(0.75),
    "MAX" : C_0_A010305.max()
})

C_0_A010305_des.COUNT.value_counts()
# Out:
# 0     1994
# 13     872
# 5       10
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 13개 중에서 9개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_0_A010305_des.loc[(C_0_A010305_des.COUNT >= 9) & (C_0_A010305_des.COUNT < 13)]
# Out:
# Empty DataFrame
# Columns: [COUNT, MEAN, STD, MIN, Q1, Q2, Q3, MAX]
# Index: []

# %% [markdown]
# ## A010305 : C_1
# - 대체 없음
#
# - 최대 카운트 35
#
# - 카운트 0 : 1989개 열
# - 카운트 15 : 10개 열
# - 카운트 1 : 5개 열

# %%
C_1_A010305 = C_1.loc[C_1.CODE_LINE == "A010305"]
C_1_A010305 = C_1_A010305.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_1_A010305.head()
# Out:
#                      Y_Quality  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  \
# TIMESTAMP
# 2022-06-21 07:14:00   0.526656  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-22 04:45:00   0.531583  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-22 12:26:00   0.530829  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-22 12:34:00   0.528270  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-23 15:50:00   0.533273  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                      ...  X_2866  X_2867  X_2868  X_2869  X_2870  X_2871  \
# TIMESTAMP            ...
# 2022-06-21 07:14:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-22 04:45:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-22 12:26:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-22 12:34:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-23 15:50:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
C_1_A010305_des = pd.DataFrame({
    "COUNT" : C_1_A010305.count(),
    "MEAN" : C_1_A010305.mean(),
    "STD" : C_1_A010305.std(),
    "MIN" : C_1_A010305.min(),
    "Q1" : C_1_A010305.quantile(0.25),
    "Q2" : C_1_A010305.quantile(0.5),
    "Q3" : C_1_A010305.quantile(0.75),
    "MAX" : C_1_A010305.max()
})

C_1_A010305_des.COUNT.value_counts()
# Out:
# 0     1989
# 35     872
# 15      10
# 1        5
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 35개 중에서 23개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_1_A010305_des.loc[(C_1_A010305_des.COUNT >= 23) & (C_1_A010305_des.COUNT < 35)]
# Out:
# Empty DataFrame
# Columns: [COUNT, MEAN, STD, MIN, Q1, Q2, Q3, MAX]
# Index: []

# %% [markdown]
# ## A010305 : C_2
# - 대체 없음
#
# - 최대 카운트 11
#
# - 카운트 0 : 1994개 열
# - 카운트 6 : 10개 열

# %%
C_2_A010305 = C_2.loc[C_2.CODE_LINE == "A010305"]
C_2_A010305 = C_2_A010305.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_2_A010305.head()
# Out:
#                      Y_Quality  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  \
# TIMESTAMP
# 2022-06-24 04:13:00   0.555514  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-24 21:38:00   0.535741  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-24 21:46:00   0.537122  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-24 22:39:00   0.536859  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-03 10:39:00   0.536433  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                      ...  X_2866  X_2867  X_2868  X_2869  X_2870  X_2871  \
# TIMESTAMP            ...
# 2022-06-24 04:13:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-24 21:38:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-24 21:46:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-24 22:39:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-07-03 10:39:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
C_2_A010305_des = pd.DataFrame({
    "COUNT" : C_2_A010305.count(),
    "MEAN" : C_2_A010305.mean(),
    "STD" : C_2_A010305.std(),
    "MIN" : C_2_A010305.min(),
    "Q1" : C_2_A010305.quantile(0.25),
    "Q2" : C_2_A010305.quantile(0.5),
    "Q3" : C_2_A010305.quantile(0.75),
    "MAX" : C_2_A010305.max()
})

C_2_A010305_des.COUNT.value_counts()
# Out:
# 0     1994
# 11     872
# 6       10
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 11개 중에서 7개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_2_A010305_des.loc[(C_2_A010305_des.COUNT >= 7) & (C_2_A010305_des.COUNT < 11)]
# Out:
# Empty DataFrame
# Columns: [COUNT, MEAN, STD, MIN, Q1, Q2, Q3, MAX]
# Index: []

# %% [markdown]
# ## A010306 : C_0
# - 대체 없음
#
# - 최대 카운트 6
#
# - 카운트 0 : 1994개 열
# - 카운트 3 : 10개 열

# %%
C_0_A010306 = C_0.loc[C_0.CODE_LINE == "A010306"]
C_0_A010306 = C_0_A010306.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_0_A010306.head()
# Out:
#                      Y_Quality  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  \
# TIMESTAMP
# 2022-06-26 03:54:00   0.513135  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-26 04:02:00   0.517938  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-29 17:07:00   0.524183  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-30 15:36:00   0.522121  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-08-02 23:26:00   0.524487  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                      ...  X_2866  X_2867  X_2868  X_2869  X_2870  X_2871  \
# TIMESTAMP            ...
# 2022-06-26 03:54:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-26 04:02:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-29 17:07:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-07-30 15:36:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-08-02 23:26:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
C_0_A010306_des = pd.DataFrame({
    "COUNT" : C_0_A010306.count(),
    "MEAN" : C_0_A010306.mean(),
    "STD" : C_0_A010306.std(),
    "MIN" : C_0_A010306.min(),
    "Q1" : C_0_A010306.quantile(0.25),
    "Q2" : C_0_A010306.quantile(0.5),
    "Q3" : C_0_A010306.quantile(0.75),
    "MAX" : C_0_A010306.max()
})

C_0_A010306_des.COUNT.value_counts()
# Out:
# 0    1994
# 6     872
# 3      10
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 6개 중에서 4개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_0_A010306_des.loc[(C_0_A010306_des.COUNT >= 4) & (C_0_A010306_des.COUNT < 6)]
# Out:
# Empty DataFrame
# Columns: [COUNT, MEAN, STD, MIN, Q1, Q2, Q3, MAX]
# Index: []

# %% [markdown]
# ## A010306 : C_1
# - 대체 없음
#
# - 최대 카운트 37
#
# - 카운트 0 : 1994개 열
# - 카운트 14 : 10개 열

# %%
C_1_A010306 = C_1.loc[C_1.CODE_LINE == "A010306"]
C_1_A010306 = C_1_A010306.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_1_A010306.head()
# Out:
#                      Y_Quality  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  \
# TIMESTAMP
# 2022-06-23 15:42:00   0.533230  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-26 06:14:00   0.526997  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-27 08:15:00   0.527735  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-01 07:54:00   0.525221  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-02 19:33:00   0.529202  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                      ...  X_2866  X_2867  X_2868  X_2869  X_2870  X_2871  \
# TIMESTAMP            ...
# 2022-06-23 15:42:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-26 06:14:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-27 08:15:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-07-01 07:54:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-07-02 19:33:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
C_1_A010306_des = pd.DataFrame({
    "COUNT" : C_1_A010306.count(),
    "MEAN" : C_1_A010306.mean(),
    "STD" : C_1_A010306.std(),
    "MIN" : C_1_A010306.min(),
    "Q1" : C_1_A010306.quantile(0.25),
    "Q2" : C_1_A010306.quantile(0.5),
    "Q3" : C_1_A010306.quantile(0.75),
    "MAX" : C_1_A010306.max()
})

C_1_A010306_des.COUNT.value_counts()
# Out:
# 0     1994
# 37     872
# 14      10
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 37개 중에서 24개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_1_A010306_des.loc[(C_1_A010306_des.COUNT >= 24) & (C_1_A010306_des.COUNT < 37)]
# Out:
# Empty DataFrame
# Columns: [COUNT, MEAN, STD, MIN, Q1, Q2, Q3, MAX]
# Index: []

# %% [markdown]
# ## A010306 : C_2
# - 대체 없음
#
# - 최대 카운트 27
#
# - 카운트 0 : 1989개 열
# - 카운트 27 : 872개 열
# - 카운트 13 : 10개 열
# - 카운트 1 : 5개 열

# %%
C_2_A010306 = C_2.loc[C_2.CODE_LINE == "A010306"]
C_2_A010306 = C_2_A010306.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_2_A010306.head()
# Out:
#                      Y_Quality  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  \
# TIMESTAMP
# 2022-06-19 20:18:00   0.540002  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-20 21:55:00   0.536206  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-21 07:06:00   0.548592  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-22 04:37:00   0.536616  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-24 04:05:00   0.547184  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                      ...  X_2866  X_2867  X_2868  X_2869  X_2870  X_2871  \
# TIMESTAMP            ...
# 2022-06-19 20:18:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-20 21:55:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-21 07:06:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-22 04:37:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2022-06-24 04:05:00  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
C_2_A010306_des = pd.DataFrame({
    "COUNT" : C_2_A010306.count(),
    "MEAN" : C_2_A010306.mean(),
    "STD" : C_2_A010306.std(),
    "MIN" : C_2_A010306.min(),
    "Q1" : C_2_A010306.quantile(0.25),
    "Q2" : C_2_A010306.quantile(0.5),
    "Q3" : C_2_A010306.quantile(0.75),
    "MAX" : C_2_A010306.max()
})

C_2_A010306_des.COUNT.value_counts()
# Out:
# 0     1989
# 27     872
# 13      10
# 1        5
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 27개 중에서 18개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_2_A010306_des.loc[(C_2_A010306_des.COUNT >= 18) & (C_2_A010306_des.COUNT < 27)]
# Out:
# Empty DataFrame
# Columns: [COUNT, MEAN, STD, MIN, Q1, Q2, Q3, MAX]
# Index: []

# %% [markdown]
# ## T100306 : C_0
# - 대체 없음
#
# - 최대 카운트 11
#
# - 카운트 0 : 2209개 열
# - 카운트 11 : 657개 열
# - 카운트 1 : 10개 열

# %%
C_0_T100306 = C_0.loc[C_0.CODE_LINE == "T100306"]
C_0_T100306 = C_0_T100306.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_0_T100306.head()
# Out:
#                      Y_Quality  X_1   X_2  X_3   X_4   X_5  X_6   X_7   X_8  \
# TIMESTAMP
# 2022-07-05 23:31:00   0.525003  2.0  93.0  0.0  45.0  10.0  0.0  54.0  10.0
# 2022-07-23 17:30:00   0.523459  2.0  95.0  0.0  45.0  10.0  0.0  53.0  10.0
# 2022-07-24 02:07:00   0.524503  1.0  93.0  0.0  45.0  10.0  0.0  51.0  10.0
# 2022-08-01 03:08:00   0.524757  2.0  91.0  0.0  45.0  10.0  0.0  57.0  10.0
# 2022-08-15 00:07:00   0.524327  2.0  87.0  0.0  45.0  10.0  0.0  50.0  10.0
#
#                       X_9  ...  X_2866  X_2867  X_2868  X_2869  X_2870  \
# TIMESTAMP                  ...
# 2022-07-05 23:31:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-07-23 17:30:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-07-24 02:07:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-08-01 03:08:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-08-15 00:07:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
C_0_T100306_des = pd.DataFrame({
    "COUNT" : C_0_T100306.count(),
    "MEAN" : C_0_T100306.mean(),
    "STD" : C_0_T100306.std(),
    "MIN" : C_0_T100306.min(),
    "Q1" : C_0_T100306.quantile(0.25),
    "Q2" : C_0_T100306.quantile(0.5),
    "Q3" : C_0_T100306.quantile(0.75),
    "MAX" : C_0_T100306.max()
})

C_0_T100306_des.COUNT.value_counts()
# Out:
# 0     2209
# 11     657
# 1       10
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 11개 중에서 7개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_0_T100306_des.loc[(C_0_T100306_des.COUNT >= 7) & (C_0_T100306_des.COUNT < 11)]
# Out:
# Empty DataFrame
# Columns: [COUNT, MEAN, STD, MIN, Q1, Q2, Q3, MAX]
# Index: []

# %% [markdown]
# ## T100306 : C_1
# - 대체 없음
#
# - 최대 카운트 144
#
# - 카운트 0 : 2204개 열
# - 카운트 36 : 10개 열
# - 카운트 7 : 5개 열

# %%
C_1_T100306 = C_1.loc[C_1.CODE_LINE == "T100306"]
C_1_T100306 = C_1_T100306.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_1_T100306.head()
# Out:
#                      Y_Quality  X_1   X_2  X_3   X_4   X_5  X_6   X_7   X_8  \
# TIMESTAMP
# 2022-06-19 09:20:00   0.531992  2.0  95.0  0.0  45.0  10.0  0.0  54.0  10.0
# 2022-06-19 23:39:00   0.528646  2.0  88.0  0.0  45.0  10.0  0.0  51.0  11.0
# 2022-06-22 03:39:00   0.529633  2.0  91.0  0.0  45.0  10.0  0.0  60.0  11.0
# 2022-06-23 03:39:00   0.530965  2.0  95.0  0.0  45.0  10.0  0.0  51.0  10.0
# 2022-06-23 06:28:00   0.529498  2.0  95.0  0.0  45.0  10.0  0.0  57.0  10.0
#
#                       X_9  ...  X_2866  X_2867  X_2868  X_2869  X_2870  \
# TIMESTAMP                  ...
# 2022-06-19 09:20:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-06-19 23:39:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-06-22 03:39:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-06-23 03:39:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-06-23 06:28:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
C_1_T100306_des = pd.DataFrame({
    "COUNT" : C_1_T100306.count(),
    "MEAN" : C_1_T100306.mean(),
    "STD" : C_1_T100306.std(),
    "MIN" : C_1_T100306.min(),
    "Q1" : C_1_T100306.quantile(0.25),
    "Q2" : C_1_T100306.quantile(0.5),
    "Q3" : C_1_T100306.quantile(0.75),
    "MAX" : C_1_T100306.max()
})

C_1_T100306_des.COUNT.value_counts()
# Out:
# 0      2204
# 144     657
# 36       10
# 7         5
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 144개 중에서 96개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_1_T100306_des.loc[(C_1_T100306_des.COUNT >= 96) & (C_1_T100306_des.COUNT < 144)]
# Out:
# Empty DataFrame
# Columns: [COUNT, MEAN, STD, MIN, Q1, Q2, Q3, MAX]
# Index: []

# %% [markdown]
# ## T100306 : C_2
# - 대체 없음
#
# - 최대 카운트 16
# - 카운트 0 : 2209개 열
# - 카운트 1 : 10개 열

# %%
C_2_T100306 = C_2.loc[C_2.CODE_LINE == "T100306"]
C_2_T100306 = C_2_T100306.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_2_T100306.head()
# Out:
#                      Y_Quality  X_1   X_2  X_3   X_4   X_5  X_6   X_7   X_8  \
# TIMESTAMP
# 2022-07-11 11:35:00   0.547902  2.0  91.0  0.0  45.0  10.0  0.0  53.0  10.0
# 2022-07-20 11:02:00   0.535403  4.0  96.0  0.0  45.0  10.0  0.0  50.0  10.0
# 2022-07-23 10:40:00   0.537060  2.0  94.0  0.0  45.0  10.0  0.0  53.0  11.0
# 2022-07-25 02:15:00   0.536183  2.0  96.0  0.0  45.0  10.0  0.0  51.0  10.0
# 2022-07-29 10:52:00   0.535622  2.0  93.0  0.0  45.0  10.0  0.0  50.0  10.0
#
#                       X_9  ...  X_2866  X_2867  X_2868  X_2869  X_2870  \
# TIMESTAMP                  ...
# 2022-07-11 11:35:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-07-20 11:02:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-07-23 10:40:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-07-25 02:15:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-07-29 10:52:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
C_2_T100306_des = pd.DataFrame({
    "COUNT" : C_2_T100306.count(),
    "MEAN" : C_2_T100306.mean(),
    "STD" : C_2_T100306.std(),
    "MIN" : C_2_T100306.min(),
    "Q1" : C_2_T100306.quantile(0.25),
    "Q2" : C_2_T100306.quantile(0.5),
    "Q3" : C_2_T100306.quantile(0.75),
    "MAX" : C_2_T100306.max()
})

C_2_T100306_des.COUNT.value_counts()
# Out:
# 0     2209
# 16     657
# 1       10
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 16개 중에서 10개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_2_T100306_des.loc[(C_2_T100306_des.COUNT >= 10) & (C_2_T100306_des.COUNT < 16)]
# Out:
# Empty DataFrame
# Columns: [COUNT, MEAN, STD, MIN, Q1, Q2, Q3, MAX]
# Index: []

# %% [markdown]
# ## A050307 : C_0
# - 최대 카운트 11
#
# - 카운트 0 : 970개 열
# - 카운트 3 : 422개 열
# - 카운트 6 : 1개 열

# %%
C_0_A050307 = C_0.loc[C_0.CODE_LINE == "A050307"]
C_0_A050307 = C_0_A050307.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_0_A050307.head()
# Out:
#                      Y_Quality  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  \
# TIMESTAMP
# 2022-07-31 00:46:00   0.522368  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-31 02:25:00   0.523383  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-07-31 06:26:00   0.524551  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-08-16 12:11:00   0.524781  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-08-25 07:52:00   0.515884  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                      ...  X_2866  X_2867  X_2868  X_2869  X_2870  X_2871  \
# TIMESTAMP            ...
# 2022-07-31 00:46:00  ...   53.23   63.10   60.41   58.94   64.95     1.0
# 2022-07-31 02:25:00  ...   50.82   61.50   56.62   57.87   67.22     1.0
# 2022-07-31 06:26:00  ...   53.40   59.90   56.30   56.83   62.83     1.0
# 2022-08-16 12:11:00  ...   54.95   56.81   42.61   57.01   65.67     1.0
# 2022-08-25 07:52:00  ...   53.37   58.32   49.10   53.29   62.48     1.0
#
# ...

# %%
C_0_A050307_des = pd.DataFrame({
    "COUNT" : C_0_A050307.count(),
    "MEAN" : C_0_A050307.mean(),
    "STD" : C_0_A050307.std(),
    "MIN" : C_0_A050307.min(),
    "Q1" : C_0_A050307.quantile(0.25),
    "Q2" : C_0_A050307.quantile(0.5),
    "Q3" : C_0_A050307.quantile(0.75),
    "MAX" : C_0_A050307.max()
})

C_0_A050307_des.COUNT.value_counts()
# Out:
# 11    1456
# 0      970
# 3      422
# 10      27
# 6        1
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 11개 중에서 7개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_0_A050307_des.loc[(C_0_A050307_des.COUNT >= 7) & (C_0_A050307_des.COUNT < 11)]
# Out:
#         COUNT       MEAN           STD        MIN         Q1         Q2  \
# X_1174     10   1.140000  2.366432e-01   1.000000   1.025000   1.100000
# X_1951     10   0.168490  2.026190e-03   0.166000   0.167275   0.167750
# X_1952     10   0.000017  1.563081e-06   0.000013   0.000017   0.000018
# X_1953     10   0.000227  2.520163e-05   0.000189   0.000203   0.000240
# X_1954     10   0.000138  1.522374e-05   0.000107   0.000129   0.000145
# X_1955     10   0.000041  3.721126e-06   0.000036   0.000038   0.000041
# X_1956     10   0.000007  8.808582e-07   0.000006   0.000007   0.000007
# X_1957     10  82.900000  5.363457e+00  71.000000  84.250000  85.000000
# X_1958     10  53.030000  1.418074e+00  50.820000  52.467500  53.200000
# X_1959     10  56.905000  3.915474e+00  51.050000  53.770000  56.905000
# X_1960     10  53.504000  5.512939e+00  42.610000  49.890000  55.245000
# X_1961     10  55.624000  3.454125e+00  48.860000  54.147500  56.920000
# ...

# %%
with open('C:\\VSC\\LG_Aimers\\2_2_Xn_txt\\C_0_A050307_7_11.txt', 'w', encoding='UTF-8') as f:
    for name in C_0_A050307_des.loc[(C_0_A050307_des.COUNT >= 7) & (C_0_A050307_des.COUNT < 11)].index:
        f.write(name+'\n')

# %%
f = open('C:\\VSC\\LG_Aimers\\2_2_Xn_txt\\C_0_A050307_7_11.txt','r')
C_0_A050307_7_11 = f.read()
f.close()
C_0_A050307_7_11
# Out:
# 'X_1174\nX_1951\nX_1952\nX_1953\nX_1954\nX_1955\nX_1956\nX_1957\nX_1958\nX_1959\nX_1960\nX_1961\nX_1962\nX_1963\nX_1964\nX_1965\nX_1966\nX_1967\nX_1968\nX_2041\nX_2042\nX_2043\nX_2866\nX_2867\nX_2868\nX_2869\nX_2870\n'

# %%
cols = ['X_1174','X_1951','X_1952','X_1953','X_1954','X_1955','X_1956','X_1957','X_1958','X_1959','X_1960','X_1961','X_1962','X_1963','X_1964','X_1965','X_1966','X_1967','X_1968','X_2041','X_2042','X_2043','X_2866','X_2867','X_2868','X_2869','X_2870']

# %%
for col in cols:
    train_df[col].loc[(train_df.Y_Class == 0) & (train_df.CODE_LINE == "A050307")] = train_df[col].loc[(train_df.Y_Class == 0) & (train_df.CODE_LINE == "A050307")].fillna(
                                                                                        train_df[col].loc[(train_df.Y_Class == 0) & (train_df.CODE_LINE == "A050307")].mean())
    
    a = train_df[col].loc[(train_df.Y_Class == 0) & (train_df.CODE_LINE == "A050307")].count()
    print("{} ... {}".format(col, a))
# Out:
# X_1174 ... 11
# X_1951 ... 11
# X_1952 ... 11
# X_1953 ... 11
# X_1954 ... 11
# X_1955 ... 11
# X_1956 ... 11
# X_1957 ... 11
# X_1958 ... 11
# X_1959 ... 11
# X_1960 ... 11
# X_1961 ... 11
# X_1962 ... 11
# X_1963 ... 11
# X_1964 ... 11
# X_1965 ... 11
# X_1966 ... 11
# X_1967 ... 11
# X_1968 ... 11
# X_2041 ... 11
# X_2042 ... 11
# X_2043 ... 11
# X_2866 ... 11
# X_2867 ... 11
# X_2868 ... 11
# X_2869 ... 11
# X_2870 ... 11
# C:\Users\LG\AppData\Local\Temp\ipykernel_4668\166456343.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[col].loc[(train_df.Y_Class == 0) & (train_df.CODE_LINE == "A050307")] = train_df[col].loc[(train_df.Y_Class == 0) & (train_df.CODE_LINE == "A050307")].fillna(

# %% [markdown]
# ## A050307 : C_1
# - 최대 카운트 9
#
# - 카운트 0 : 900개 열
# - 카운트 1 : 492개 열
# - 카운트 4 : 1개 열

# %%
C_1_A050307 = C_1.loc[C_1.CODE_LINE == "A050307"]
C_1_A050307 = C_1_A050307.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_1_A050307.head()
# Out:
#                      Y_Quality  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  \
# TIMESTAMP
# 2022-06-21 17:44:00   0.527976  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-08-03 01:20:00   0.534843  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-08-12 08:35:00   0.532386  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-08-13 14:21:00   0.527944  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-08-14 12:30:00   0.525086  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                      ...  X_2866  X_2867  X_2868  X_2869  X_2870  X_2871  \
# TIMESTAMP            ...
# 2022-06-21 17:44:00  ...     NaN     NaN     NaN     NaN     NaN     1.0
# 2022-08-03 01:20:00  ...     NaN     NaN     NaN     NaN     NaN     1.0
# 2022-08-12 08:35:00  ...   55.40   59.57   42.58   57.58   64.90     1.0
# 2022-08-13 14:21:00  ...   55.18   53.54   47.58   53.70   61.95     1.0
# 2022-08-14 12:30:00  ...   55.69   53.03   53.75   58.96   64.01     1.0
#
# ...

# %%
C_1_A050307_des = pd.DataFrame({
    "COUNT" : C_1_A050307.count(),
    "MEAN" : C_1_A050307.mean(),
    "STD" : C_1_A050307.std(),
    "MIN" : C_1_A050307.min(),
    "Q1" : C_1_A050307.quantile(0.25),
    "Q2" : C_1_A050307.quantile(0.5),
    "Q3" : C_1_A050307.quantile(0.75),
    "MAX" : C_1_A050307.max()
})

C_1_A050307_des.COUNT.value_counts()
# Out:
# 9    1453
# 0     900
# 1     492
# 7      26
# 6       3
# 8       1
# 4       1
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 9개 중에서 6개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_1_A050307_des.loc[(C_1_A050307_des.COUNT >= 6) & (C_1_A050307_des.COUNT < 9)]
# Out:
#         COUNT           MEAN           STD            MIN             Q1  \
# X_990       6     163.833333  4.082483e-01     163.000000     164.000000
# X_991       6  114166.666667  1.417627e+04  101000.000000  102000.000000
# X_1174      8       1.012500  8.345230e-02       0.900000       0.975000
# X_1175      6      11.833333  4.082483e-01      11.000000      12.000000
# X_1951      7       0.164748  1.654685e-03       0.162200       0.164150
# X_1952      7       0.000014  4.212437e-06       0.000006       0.000013
# X_1953      7       0.000235  9.478879e-06       0.000219       0.000230
# X_1954      7       0.000081  4.466127e-05       0.000044       0.000046
# X_1955      7       0.000037  3.545621e-06       0.000030       0.000035
# X_1956      7       0.000008  6.466691e-07       0.000006       0.000007
# X_1957      7      74.571429  1.653136e+01      51.000000      69.500000
# X_1958      7      53.967143  1.430731e+00      52.280000      52.790000
# ...

# %%
with open('C:\\VSC\\LG_Aimers\\2_2_Xn_txt\\C_1_A050307_6_9.txt', 'w', encoding='UTF-8') as f:
    for name in C_1_A050307_des.loc[(C_1_A050307_des.COUNT >= 6) & (C_1_A050307_des.COUNT < 9)].index:
        f.write(name+'\n')

# %%
f = open('C:\\VSC\\LG_Aimers\\2_2_Xn_txt\\C_1_A050307_6_9.txt','r')
C_1_A050307_6_9 = f.read()
f.close()
C_1_A050307_6_9
# Out:
# 'X_990\nX_991\nX_1174\nX_1175\nX_1951\nX_1952\nX_1953\nX_1954\nX_1955\nX_1956\nX_1957\nX_1958\nX_1959\nX_1960\nX_1961\nX_1962\nX_1963\nX_1964\nX_1965\nX_1966\nX_1967\nX_1968\nX_2041\nX_2042\nX_2043\nX_2866\nX_2867\nX_2868\nX_2869\nX_2870\n'

# %%
cols = ['X_990','X_991','X_1174','X_1175','X_1951','X_1952','X_1953','X_1954','X_1955','X_1956','X_1957','X_1958','X_1959','X_1960','X_1961','X_1962','X_1963','X_1964','X_1965','X_1966','X_1967','X_1968','X_2041','X_2042','X_2043','X_2866','X_2867','X_2868','X_2869','X_2870']

# %%
for col in cols:
    train_df[col].loc[(train_df.Y_Class == 1) & (train_df.CODE_LINE == "A050307")] = train_df[col].loc[(train_df.Y_Class == 1) & (train_df.CODE_LINE == "A050307")].fillna(
                                                                                        train_df[col].loc[(train_df.Y_Class == 1) & (train_df.CODE_LINE == "A050307")].mean())
    
    a = train_df[col].loc[(train_df.Y_Class == 1) & (train_df.CODE_LINE == "A050307")].count()
    print("{} ... {}".format(col, a))
# Out:
# X_990 ... 9
# X_991 ... 9
# X_1174 ... 9
# X_1175 ... 9
# X_1951 ... 9
# X_1952 ... 9
# X_1953 ... 9
# X_1954 ... 9
# X_1955 ... 9
# X_1956 ... 9
# X_1957 ... 9
# X_1958 ... 9
# X_1959 ... 9
# X_1960 ... 9
# X_1961 ... 9
# X_1962 ... 9
# X_1963 ... 9
# X_1964 ... 9
# X_1965 ... 9
# X_1966 ... 9
# X_1967 ... 9
# X_1968 ... 9
# X_2041 ... 9
# X_2042 ... 9
# X_2043 ... 9
# X_2866 ... 9
# X_2867 ... 9
# X_2868 ... 9
# X_2869 ... 9
# X_2870 ... 9
# C:\Users\LG\AppData\Local\Temp\ipykernel_4668\4160644616.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[col].loc[(train_df.Y_Class == 1) & (train_df.CODE_LINE == "A050307")] = train_df[col].loc[(train_df.Y_Class == 1) & (train_df.CODE_LINE == "A050307")].fillna(

# %% [markdown]
# ## A050307 : C_2
# - 최대 카운트 22
#
# - 카운트 0 : 900개 열
# - 카운트 13 : 70개 열
# - 카운트 12 : 1개 열

# %%
C_2_A050307 = C_2.loc[C_2.CODE_LINE == "A050307"]
C_2_A050307 = C_2_A050307.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_2_A050307.head()
# Out:
#                      Y_Quality  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  \
# TIMESTAMP
# 2022-06-13 05:22:00   0.541819  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-13 05:39:00   0.537325  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-13 05:55:00   0.537833  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-13 06:11:00   0.540003  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2022-06-13 06:28:00   0.538049  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                      ...  X_2866  X_2867  X_2868  X_2869  X_2870  X_2871  \
# TIMESTAMP            ...
# 2022-06-13 05:22:00  ...   38.89   42.82   43.92   35.34   72.55     NaN
# 2022-06-13 05:39:00  ...   37.74   39.17   52.17   30.58   71.78     NaN
# 2022-06-13 05:55:00  ...   38.16   51.25   56.01   37.41   71.37     NaN
# 2022-06-13 06:11:00  ...   39.00   35.95   59.51   30.49   72.77     NaN
# 2022-06-13 06:28:00  ...   34.40   35.88   50.36   38.45   71.42     NaN
#
# ...

# %%
C_2_A050307_des = pd.DataFrame({
    "COUNT" : C_2_A050307.count(),
    "MEAN" : C_2_A050307.mean(),
    "STD" : C_2_A050307.std(),
    "MIN" : C_2_A050307.min(),
    "Q1" : C_2_A050307.quantile(0.25),
    "Q2" : C_2_A050307.quantile(0.5),
    "Q3" : C_2_A050307.quantile(0.75),
    "MAX" : C_2_A050307.max()
})

C_2_A050307_des.COUNT.value_counts()
# Out:
# 22    1455
# 0      900
# 19     422
# 13      70
# 16      27
# 18       1
# 12       1
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 22개 중에서 14개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_2_A050307_des.loc[(C_2_A050307_des.COUNT >= 14) & (C_2_A050307_des.COUNT < 22)]
# Out:
#         COUNT        MEAN         STD        MIN          Q1          Q2  \
# X_1408     18   31.671985   23.409295  -0.554926   13.985484   31.000000
# X_1540     16  438.215289  326.559204  74.386555  301.449731  370.134728
# X_1951     16    0.170750    0.001942   0.165800    0.170275    0.170750
# X_1952     16    0.000016    0.000005   0.000006    0.000016    0.000016
# X_1953     16    0.000187    0.000010   0.000176    0.000183    0.000184
# ...       ...         ...         ...        ...         ...         ...
# X_2866     16   44.895000    9.191007  33.160000   38.127500   39.790000
# X_2867     16   47.978750   11.592351  33.260000   35.932500   47.890000
# X_2868     16   50.396250    7.451966  40.970000   41.955000   51.265000
# X_2869     16   44.506875   11.363043  30.490000   35.297500   39.395000
# X_2870     16   69.230625    3.684317  63.400000   65.660000   71.385000
#
#                 Q3          MAX
# X_1408   40.723773    78.000000
# ...

# %%
with open('C:\\VSC\\LG_Aimers\\2_2_Xn_txt\\C_2_A050307_14_22.txt', 'w', encoding='UTF-8') as f:
    for name in C_2_A050307_des.loc[(C_2_A050307_des.COUNT >= 14) & (C_2_A050307_des.COUNT < 22)].index:
        f.write(name+'\n')

# %%
f = open('C:\\VSC\\LG_Aimers\\2_2_Xn_txt\\C_2_A050307_14_22.txt','r')
C_2_A050307_14_22 = f.read()
f.close()
C_2_A050307_14_22
# Out:
py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[col].loc[(train_df.Y_Class == 2) & (train_df.CODE_LINE == "A050307")] = train_df[col].loc[(train_df.Y_Class == 2) & (train_df.CODE_LINE == "A050307")].fillna(
# X_1408 ... 22
# X_1540 ... 22
# X_1951 ... 22
# X_1952 ... 22
# X_1953 ... 22
# X_1954 ... 22
# X_1955 ... 22
# X_1956 ... 22
# X_1957 ... 22
# X_1958 ... 22
# X_1959 ... 22
# X_1960 ... 22
# X_1961 ... 22
# X_1962 ... 22
# X_1963 ... 22
# X_1964 ... 22
# X_1965 ... 22
# X_1966 ... 22
# X_1967 ... 22
# X_1968 ... 22
# X_2041 ... 22
# X_2042 ... 22
# X_2043 ... 22
# X_2063 ... 22
# X_2064 ... 22
# X_2065 ... 22
# X_2066 ... 22
# X_2067 ... 22
# X_2068 ... 22
# X_2070 ... 22
# X_2071 ... 22
# X_2072 ... 22
# X_2073 ... 22
# ...

# %% [markdown]
# ## **1, 2 : 겹치는 CODE_LINE**
#
# - O100306

# %% [markdown]
# ## O100306 : C_1
# - 대체 없음
#
# - 최대 카운트 1
#
# - 카운트 0 : 2214개 열

# %%
C_1_O100306 = C_1.loc[C_1.CODE_LINE == "O100306"]
C_1_O100306 = C_1_O100306.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_1_O100306.head()
# Out:
#                      Y_Quality   X_1   X_2  X_3   X_4   X_5  X_6   X_7   X_8  \
# TIMESTAMP
# 2022-09-08 14:46:00   0.533702  21.0  87.0  0.0  45.0  10.0  0.0  61.0  10.0
#
#                       X_9  ...  X_2866  X_2867  X_2868  X_2869  X_2870  \
# TIMESTAMP                  ...
# 2022-09-08 14:46:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
#
#                      X_2871  X_2872  X_2873  X_2874  X_2875
# TIMESTAMP
# 2022-09-08 14:46:00     NaN     NaN     NaN     NaN     NaN
#
# [1 rows x 2876 columns]

# %%
C_1_O100306_des = pd.DataFrame({
    "COUNT" : C_1_O100306.count(),
    "MEAN" : C_1_O100306.mean(),
    "STD" : C_1_O100306.std(),
    "MIN" : C_1_O100306.min(),
    "Q1" : C_1_O100306.quantile(0.25),
    "Q2" : C_1_O100306.quantile(0.5),
    "Q3" : C_1_O100306.quantile(0.75),
    "MAX" : C_1_O100306.max()
})

C_1_O100306_des.COUNT.value_counts()
# Out:
# 0    2214
# 1     662
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 1

# %% [markdown]
# ## O100306 : C_2
# - 대체 없음
#
# - 최대 카운트 2
#
# - 카운트 0 : 2219개 열

# %%
C_2_O100306 = C_2.loc[C_2.CODE_LINE == "O100306"]
C_2_O100306 = C_2_O100306.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_2_O100306.head()
# Out:
#                      Y_Quality  X_1   X_2  X_3   X_4   X_5  X_6   X_7   X_8  \
# TIMESTAMP
# 2022-09-03 18:40:00   0.534951  6.0  90.0  0.0  45.0  10.0  0.0  51.0  10.0
# 2022-09-03 18:56:00   0.535205  6.0  89.0  0.0  45.0  10.0  0.0  51.0  10.0
#
#                       X_9  ...  X_2866  X_2867  X_2868  X_2869  X_2870  \
# TIMESTAMP                  ...
# 2022-09-03 18:40:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-09-03 18:56:00  52.0  ...     NaN     NaN     NaN     NaN     NaN
#
#                      X_2871  X_2872  X_2873  X_2874  X_2875
# TIMESTAMP
# 2022-09-03 18:40:00     NaN     NaN     NaN     NaN     NaN
# 2022-09-03 18:56:00     NaN     NaN     NaN     NaN     NaN
#
# [2 rows x 2876 columns]

# %%
C_2_O100306_des = pd.DataFrame({
    "COUNT" : C_2_O100306.count(),
    "MEAN" : C_2_O100306.mean(),
    "STD" : C_2_O100306.std(),
    "MIN" : C_2_O100306.min(),
    "Q1" : C_2_O100306.quantile(0.25),
    "Q2" : C_2_O100306.quantile(0.5),
    "Q3" : C_2_O100306.quantile(0.75),
    "MAX" : C_2_O100306.max()
})

C_2_O100306_des.COUNT.value_counts()
# Out:
# 0    2219
# 2     657
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 2

# %% [markdown]
# ## **1 : 안 겹치는 CODE_LINE**
#
# - O100304

# %% [markdown]
# ## O100304 : C_1
# - 대체 없음
#
# - 최대 카운트 3
#
# - 카운트 0 : 2214개 열
# - 카운트 1 : 5개 열

# %%
C_1_O100304 = C_1.loc[C_1.CODE_LINE == "O100304"]
C_1_O100304 = C_1_O100304.drop(columns=["Y_Class", "LINE", "PRODUCT_CODE", "CODE_LINE"])
C_1_O100304.head()
# Out:
#                      Y_Quality   X_1    X_2  X_3   X_4   X_5  X_6   X_7   X_8  \
# TIMESTAMP
# 2022-09-03 18:32:00   0.530533   4.0   98.0  0.0  45.0  11.0  0.0  45.0  10.0
# 2022-09-03 18:48:00   0.525916   4.0  100.0  0.0  45.0  11.0  0.0  45.0  10.0
# 2022-09-08 14:38:00   0.531375  40.0   94.0  0.0  45.0  11.0  0.0  45.0  10.0
#
#                       X_9  ...  X_2866  X_2867  X_2868  X_2869  X_2870  \
# TIMESTAMP                  ...
# 2022-09-03 18:32:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-09-03 18:48:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
# 2022-09-08 14:38:00  31.0  ...     NaN     NaN     NaN     NaN     NaN
#
#                      X_2871  X_2872  X_2873  X_2874  X_2875
# TIMESTAMP
# 2022-09-03 18:32:00     NaN     NaN     NaN     NaN     NaN
# 2022-09-03 18:48:00     NaN     NaN     NaN     NaN     NaN
# 2022-09-08 14:38:00     NaN     NaN     NaN     NaN     NaN
#
# [3 rows x 2876 columns]

# %%
C_1_O100304_des = pd.DataFrame({
    "COUNT" : C_1_O100304.count(),
    "MEAN" : C_1_O100304.mean(),
    "STD" : C_1_O100304.std(),
    "MIN" : C_1_O100304.min(),
    "Q1" : C_1_O100304.quantile(0.25),
    "Q2" : C_1_O100304.quantile(0.5),
    "Q3" : C_1_O100304.quantile(0.75),
    "MAX" : C_1_O100304.max()
})

C_1_O100304_des.COUNT.value_counts()
# Out:
# 0    2214
# 3     657
# 1       5
# Name: COUNT, dtype: int64

# %% [markdown]
# - 최대 카운트 3개 중에서 2개 이상인 각 X 변수에 각 평균으로 대체

# %%
C_1_O100304_des.loc[(C_1_O100304_des.COUNT >= 2) & (C_1_O100304_des.COUNT < 3)]
# Out:
# Empty DataFrame
# Columns: [COUNT, MEAN, STD, MIN, Q1, Q2, Q3, MAX]
# Index: []

# %% [markdown]
# ---

# %%
train_df
# Out:
#                      Y_Class  Y_Quality     LINE PRODUCT_CODE CODE_LINE   X_1  \
# TIMESTAMP
# 2022-06-13 05:14:00        1   0.533433  T050304            A   A050304   NaN
# 2022-06-13 05:22:00        2   0.541819  T050307            A   A050307   NaN
# 2022-06-13 05:30:00        1   0.531267  T050304            A   A050304   NaN
# 2022-06-13 05:39:00        2   0.537325  T050307            A   A050307   NaN
# 2022-06-13 05:47:00        1   0.531590  T050304            A   A050304   NaN
# ...                      ...        ...      ...          ...       ...   ...
# 2022-09-08 14:30:00        1   0.526546  T100306            T   T100306   2.0
# 2022-09-08 22:38:00        0   0.524022  T050304            A   A050304   NaN
# 2022-09-08 22:47:00        0   0.521289  T050304            A   A050304   NaN
# 2022-09-08 14:38:00        1   0.531375  T100304            O   O100304  40.0
# 2022-09-08 14:46:00        1   0.533702  T100306            O   O100306  21.0
#
# ...

# %%
a = train_df.loc[train_df.Y_Class == 0]
b = train_df.loc[train_df.Y_Class == 1]
c = train_df.loc[train_df.Y_Class == 2]

C_0 = a
C_1 = b
C_2 = c

# %%
C_0.describe()
# Out:
#        Y_Class  Y_Quality        X_1         X_2   X_3   X_4        X_5   X_6  \
# count     88.0  88.000000  28.000000   28.000000  28.0  28.0  28.000000  28.0
# mean       0.0   0.520837   1.928571   96.500000   0.0  45.0  10.464286   0.0
# std        0.0   0.004603   0.377964    4.367388   0.0   0.0   0.507875   0.0
# min        0.0   0.500856   1.000000   87.000000   0.0  45.0  10.000000   0.0
# 25%        0.0   0.519440   2.000000   93.000000   0.0  45.0  10.000000   0.0
# 50%        0.0   0.522054   2.000000   97.000000   0.0  45.0  10.000000   0.0
# 75%        0.0   0.524113   2.000000  100.250000   0.0  45.0  11.000000   0.0
# max        0.0   0.525067   3.000000  102.000000   0.0  45.0  11.000000   0.0
#
#              X_7   X_8  ...     X_2866     X_2867     X_2868     X_2869  \
# count  28.000000  28.0  ...  41.000000  41.000000  41.000000  41.000000
# mean   47.892857  10.0  ...  53.058354  56.011707  50.569366  55.684488
# ...

# %%
C_1.describe()
# Out:
#        Y_Class   Y_Quality         X_1         X_2    X_3    X_4         X_5  \
# count    407.0  407.000000  289.000000  289.000000  289.0  289.0  289.000000
# mean       1.0    0.530253    2.480969   95.048443    0.0   45.0   10.401384
# std        0.0    0.002444    6.466298    4.100864    0.0    0.0    0.491029
# min        1.0    0.525086    1.000000   87.000000    0.0   45.0   10.000000
# 25%        1.0    0.528378    2.000000   93.000000    0.0   45.0   10.000000
# 50%        1.0    0.530308    2.000000   95.000000    0.0   45.0   10.000000
# 75%        1.0    0.532129    2.000000   98.000000    0.0   45.0   11.000000
# max        1.0    0.534843  103.000000  102.000000    0.0   45.0   11.000000
#
#          X_6         X_7         X_8  ...     X_2866     X_2867     X_2868  \
# count  289.0  289.000000  289.000000  ...  46.000000  46.000000  46.000000
# mean     0.0   48.858131   10.048443  ...  50.598987  52.900734  48.950878
# ...

# %%
C_2.describe()
# Out:
#        Y_Class   Y_Quality        X_1         X_2   X_3   X_4        X_5  \
# count    103.0  103.000000  32.000000   32.000000  32.0  32.0  32.000000
# mean       2.0    0.542031   2.187500   94.593750   0.0  45.0  10.250000
# std        0.0    0.008038   1.119836    3.808813   0.0   0.0   0.439941
# min        2.0    0.534951   1.000000   87.000000   0.0  45.0  10.000000
# 25%        2.0    0.536354   2.000000   92.500000   0.0  45.0  10.000000
# 50%        2.0    0.538508   2.000000   95.000000   0.0  45.0  10.000000
# 75%        2.0    0.546555   2.000000   96.250000   0.0  45.0  10.250000
# max        2.0    0.578841   6.000000  102.000000   0.0  45.0  11.000000
#
#         X_6        X_7        X_8  ...     X_2866     X_2867     X_2868  \
# count  32.0  32.000000  32.000000  ...  33.000000  33.000000  33.000000
# mean    0.0  49.093750  10.093750  ...  48.010741  51.333981  49.424167
# std     0.0   4.098461   0.296145  ...   7.839476   9.398505   6.701780
# ...
